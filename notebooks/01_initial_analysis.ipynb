# %%
import sys
sys.path.append('../src')  # Allow imports from src/

from data_utils import load_raw_data, clean_data, save_cleaned_data
from analysis import analyze_all  # ✅ Should work now

# File paths
raw_filepath = "../data/raw/dataset_Facebook.csv"
cleaned_filepath = "../data/processed/cleaned_dataset_Facebook.csv"

# Load, clean, and save data
df = load_raw_data(raw_filepath)
df = clean_data(df)
save_cleaned_data(df, cleaned_filepath)

# Perform analysis (Generate all 4 plots in the same figure)
analyze_all(df)
# Out:
# ✅ Cleaned dataset saved at: ../data/processed/cleaned_dataset_Facebook.csv
